# %% [markdown]
# # Drawing in Python: Part 2
# ## Functions and choices
#
# Hi everyone!
#
# Welcome back to our introduction to Python programming via drawing with turtle graphics!
#
# This time we're going to cover a few more important concepts that let us do even more with our code, including the ability to define our own "verbs" that will let us simplify and reuse code.

# %% [markdown]
# # Run this before you do anything else

# %%
# !pip install ColabTurtle

from ColabTurtle.Turtle import *
# Out:
# Collecting ColabTurtle
#   Downloading ColabTurtle-2.1.0.tar.gz (6.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=e5c689f2f5c6c887ed65255cef4bdd0d9627041a636d752fc0663280b0cd3084
#   Stored in directory: /root/.cache/pip/wheels/5b/86/e8/54f5c8c853606e3a3060bb2e60363cbed632374a12e0f33ffc
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.1.0

# %% [markdown]
# # Review
# So last time we saw how to do some basic drawing, change color, and use for-loops to try and handle repetition.
#
# Here's a code example that covers all of those concepts at once: drawing a series of triangles with different colors

# %%
initializeTurtle()

penup() # this lets you move without drawing
color('red') # set the color by passing the function a "string"
goto(100,100) # we move on the plane by giving goto two numbers
pendown() # we put the pen back down
for i in range(0,3): # Pop quiz: what values does i take in this loop? how many times does it run?
  forward(30) # move forward by 30
  right(120) # turn to the right 120 degrees (three sides * 120 = 360 so you should end facing the way you started)

# okay now we do all of it again
penup()
color('blue')
goto(200,200)
pendown()
for i in range(0,3):
  forward(30)
  right(120)

# okay now we do it all *again*
penup()
color('green')
goto(300,300)
pendown()
for i in range(0,3):
  forward(30)
  right(120)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="100" y1="100" x2="100.0" y2="70.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="100.0" y1="70.0" x2="125.981" y2="85.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="125.981" y1="85.0" x2="100.0" y2="100.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="200" y1="200" x2="200.0" y2="170.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="200.0" y1="170.0" x2="225.981" y2="185.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="225.981" y1="185.0" x2="200.0" y2="200.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="300" y1="300" x2="300.0" y2="270.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="300.0" y1="270.0" x2="325.981" y2="285.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="325.981" y1="285.0" x2="300.0" y2="300.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,300.0,300.0) translate(282.0, 282.0)">
# <path style=" stroke:none;fill-rule:evenodd;fill:green;fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>

# %% [markdown]
# If you look at this code there's obviously a lot of *repetition*. You probably also felt this if, in the previous assignment, you ended up trying to make something really elaborate.
#
# So the first thing we're going to introduce is the idea of how encapsulate, that is *reuse*, code into a new verb that we can call. These "verbs" are, in most programming languages, called *functions*.
#
# Our very first example is drawing a triangle

# %%
initializeTurtle()

def triangle():
  for i in range(0,3):
    forward(30)
    right(120)

penup() # this lets you move without drawing
color('red') # set the color by passing the function a "string"
goto(100,100) # we move on the plane by giving goto two numbers
pendown() # we put the pen back down
triangle()

# okay now we do all of it again
penup()
color('blue')
goto(200,200)
pendown()
triangle()

# okay now we do it all *again*
penup()
color('green')
goto(300,300)
pendown()
triangle()

# %% [markdown]
# you can see that we've made a function called *triangle*
#
# Function definitions always start with `def`, followed by a space, and then the name of the function, then the arguments it takes listed in parentheses. This first function takes *no* arguments so that's why we have just `()`.
#
# The same way that with, a for-loop, after the colon we indent code to show that it "belongs-to" the context of the for-loop, we indent all the code after the colon here to tell Python that *this* is the code that should be run every time we use the function.
#
# You can see that this reduces a fair bit of the redundancy by only having to write the for-loop once.
#
# Okay take a second and think about what other things it'd be nice to include in this function instead to reduce redundancy.
#
# ## Your thoughts here!

# %% [markdown]
# ## My turn
# Okay, so there are a few things we could do to make this function more useful. The first is that we can make our function take the *color* to draw, like this

# %%
initializeTurtle()

def triangle(triColor):
  color(triColor)
  for i in range(0,3):
    forward(30)
    right(120)

penup() # this lets you move without drawing
goto(100,100) # we move on the plane by giving goto two numbers
pendown() # we put the pen back down
triangle('red')

# okay now we do all of it again
penup()
goto(200,200)
pendown()
triangle('blue')

# okay now we do it all *again*
penup()
goto(300,300)
pendown()
triangle('green')
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="100" y1="100" x2="100.0" y2="70.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="100.0" y1="70.0" x2="125.981" y2="85.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="125.981" y1="85.0" x2="100.0" y2="100.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="200" y1="200" x2="200.0" y2="170.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="200.0" y1="170.0" x2="225.981" y2="185.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="225.981" y1="185.0" x2="200.0" y2="200.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="300" y1="300" x2="300.0" y2="270.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="300.0" y1="270.0" x2="325.981" y2="285.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="325.981" y1="285.0" x2="300.0" y2="300.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,300.0,300.0) translate(282.0, 282.0)">
# <path style=" stroke:none;fill-rule:evenodd;fill:green;fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>

# %% [markdown]
# Okay so how could we make this better? Probably by putting the `goto` inside the function by adding `x` and `y` arguments to the function too. This also lets us move the `penup` and `pendown` inside the function too!

# %%
initializeTurtle()

def triangle(x,y,triColor):
  penup()
  goto(x,y)
  pendown()
  color(triColor)
  for i in range(0,3):
    forward(30)
    right(120)


triangle(100,100,'red')
triangle(200,200,'blue')
triangle(300,300,'green')
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="100" y1="100" x2="100.0" y2="70.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="100.0" y1="70.0" x2="125.981" y2="85.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="125.981" y1="85.0" x2="100.0" y2="100.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="200" y1="200" x2="200.0" y2="170.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="200.0" y1="170.0" x2="225.981" y2="185.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="225.981" y1="185.0" x2="200.0" y2="200.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="300" y1="300" x2="300.0" y2="270.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="300.0" y1="270.0" x2="325.981" y2="285.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="325.981" y1="285.0" x2="300.0" y2="300.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,300.0,300.0) translate(282.0, 282.0)">
# <path style=" stroke:none;fill-rule:evenodd;fill:green;fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>

# %% [markdown]
# Now this is a nice start but we can make it even *more* general by also letting the length of the triangle be a variable *as well as the number of sides*
#
# So we're very close to just making a general function that lets us draw any shape!
#
# In fact, try doing that in the space below before I do it myself

# %%
# put your code here!

# %% [markdown]
# ## My turn

# %%
initializeTurtle()

def shape(x,y,sides,length,triColor):
  penup()
  goto(x,y)
  pendown()
  color(triColor)
  for i in range(0,sides):
    forward(length)
    right(360/sides)


shape(100,100,3,30,'red')
shape(200,200,5,50,'blue')
shape(300,300,7,70,'green')
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="100" y1="100" x2="100.0" y2="70.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="100.0" y1="70.0" x2="125.981" y2="85.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="125.981" y1="85.0" x2="100.0" y2="100.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="200" y1="200" x2="200.0" y2="150.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="200.0" y1="150.0" x2="247.553" y2="134.549" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="247.553" y1="134.549" x2="276.942" y2="175.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="276.942" y1="175.0" x2="247.553" y2="215.451" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="247.553" y1="215.451" x2="200.0" y2="200.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="300" y1="300" x2="300.0" y2="230.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="300.0" y1="230.0" x2="354.728" y2="186.356" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="354.728" y1="186.356" x2="422.973" y2="201.932" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="422.973" y1="201.932" x2="453.345" y2="265.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="453.345" y1="265.0" x2="422.973" y2="328.068" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="422.973" y1="328.068" x2="354.728" y2="343.644" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="354.728" y1="343.644" x2="300.0" y2="300.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360.00000000000006,300.0,300.0) translate(282.0, 282.0)">
# <path style=" stroke:none;fill-rule:evenodd;fill:green;fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>

# %% [markdown]
# # Making choices
# The other concept we want to introduce is how to make *choices* in Python. This is going to be done with the if-statement, which lets us ask a question about the state of our program and then do something dependent on that answer.
#
# Here's a first, admittedly silly, example where we're going to use our function above and draw shapes moving across the screen and if we're on the left hand side we'll be making the shapes blue and if we're on the right hand side we'll be making the shapes green.

# %%
initializeTurtle()

# first we need to figure out how big the screen is: but the turtle graphics code gives us a way to do that!
# we have a window_width function that gives us the width of the screen
# and a window_height function that gives us the height of the screen

# this is setup code to put our turtle in the right place, the left hand side
ourX = 0
ourY = window_height()/2

for i in range(0,10):
  # here we *ask* our question
  if ourX < window_width()/2:
    # we can use the shape function as long as we're run all the code up until now
    shape(ourX,ourY,3,30,'blue' )
  else: # here we decide what to do if the answer to the question is "no"
    shape(ourX,ourY,3,30,'green')
  ourX = ourX + window_width()/10
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="0" y1="250.0" x2="-0.0" y2="220.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="-0.0" y1="220.0" x2="25.981" y2="235.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="25.981" y1="235.0" x2="0.0" y2="250.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="80.0" y1="250.0" x2="80.0" y2="220.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="80.0" y1="220.0" x2="105.981" y2="235.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="105.981" y1="235.0" x2="80.0" y2="250.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="160.0" y1="250.0" x2="160.0" y2="220.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="160.0" y1="220.0" x2="185.981" y2="235.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="185.981" y1="235.0" x2="160.0" y2="250.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="240.0" y1="250.0" x2="240.0" y2="220.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="240.0" y1="220.0" x2="265.981" y2="235.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="265.981" y1="235.0" x2="240.0" y2="250.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="320.0" y1="250.0" x2="320.0" y2="220.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="320.0" y1="220.0" x2="345.981" y2="235.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="345.981" y1="235.0" x2="320.0" y2="250.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="400.0" y1="250.0" x2="400.0" y2="220.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="400.0" y1="220.0" x2="425.981" y2="235.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="425.981" y1="235.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="480.0" y1="250.0" x2="480.0" y2="220.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="480.0" y1="220.0" x2="505.981" y2="235.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="505.981" y1="235.0" x2="480.0" y2="250.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="560.0" y1="250.0" x2="560.0" y2="220.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="560.0" y1="220.0" x2="585.981" y2="235.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="585.981" y1="235.0" x2="560.0" y2="250.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="640.0" y1="250.0" x2="640.0" y2="220.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="640.0" y1="220.0" x2="665.981" y2="235.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="665.981" y1="235.0" x2="640.0" y2="250.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="720.0" y1="250.0" x2="720.0" y2="220.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="720.0" y1="220.0" x2="745.981" y2="235.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="745.981" y1="235.0" x2="720.0" y2="250.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360.0,720.0,250.0) translate(702.0, 232.0)">
# <path style=" stroke:none;fill-rule:evenodd;fill:green;fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>

# %% [markdown]
# Okay, so now what if we want to change this code so that it
#
#
# 1.   Starts in the upper-left corner instead
# 2.   If in the upper side of the screen it has 3 sides and in the lower half it's 5 sides
#
# Now we're going to need the ability to make our if-statement more complicated by using the `elif` statement, which lets us make additional choices in order, as well as the `and` operator that lets us combine questions!

# %%
initializeTurtle()

speed(13)

ourX = 0
ourY = window_height()/4

deltaX = window_width()/10
deltaY = window_height()/10

for i in range(0,10):
  # here we *ask* our question
  if ourX < window_width()/2 and ourY < window_height()/2:
    # we can use the shape function as long as we're run all the code up until now
    shape(ourX,ourY,3,30,'blue')
  elif ourX < window_width()/2 and ourY >= window_height()/2:
    shape(ourX,ourY,5,30,'blue')
  elif ourX >= window_width()/2 and ourY < window_height()/2:
    shape(ourX,ourY,3,30,'green')
  else: # here we decide what to do if the answer to the question is "no"
    shape(ourX,ourY,5,30,'green')
  ourX = ourX + deltaX
  ourY = ourY + deltaY

# %% [markdown]
# ## Bouncing around the screen
# Okay so there's one thing that's sort of annoying about this example which is that we run off the edge of the screen.
#
# Y'know what's good for that? We can check whether or not our ourX and ourY variables are off the edge of the screen?
#
# Take a second before reading ahead and think about what that might look like!

# %% [markdown]
# ## My turn again

# %%
initializeTurtle()

speed(13)

ourX = 0
ourY = window_height()/4

deltaX = window_width()/10
deltaY = window_height()/10

for i in range(0,15):
  # here we *ask* our question
  if ourX < window_width()/2 and ourY < window_height()/2:
    # we can use the shape function as long as we're run all the code up until now
    shape(ourX,ourY,3,30,'blue')
  elif ourX < window_width()/2 and ourY >= window_height()/2:
    shape(ourX,ourY,5,30,'blue')
  elif ourX >= window_width()/2 and ourY < window_height()/2:
    shape(ourX,ourY,3,30,'green')
  else: # here we decide what to do if the answer to the question is "no"
    shape(ourX,ourY,5,30,'green')
  ourX = ourX + deltaX
  if ourX >= window_width():
    # now we need to make ourX go back the other way
    ourX = ourX - 2*deltaX # we fix our mistake
    deltaX = -deltaX # now we change the direction we're moving
  ourY = ourY + deltaY
  if ourY >= window_height():
    ourY = ourY - 2*deltaY/10
    deltaY = -deltaY

# %% [markdown]
# ## Okay now what?
# This is better but it honestly still has some problems. This handles if ourX and ourY are too big but what happens if they're too small?
#
# We need a new kind of way of combining questions, one that lets us make a decision on whether one thing is true *or* the other thing is true.
#
# That word "or" is really important!
#
# So take a minute, modify the code above to check whether
#
# `ourY >= window_height() or ourY < 0`
#
# and to check whether
#
# `ourX >= window_width() or ourX < 0`
#
# instead then change the range of the for loop so that it goes a whole bunch of times, then watch what happens!!

# %% [markdown]
# # Your assignment
# So your assignment is to take what we've learned in this document and make a *new* drawing below. To get full credit this one should have at least *one* function (other than the triangle and shape functions we made together) that abstracts out drawing a repeated element!

# %%
# your code goes here

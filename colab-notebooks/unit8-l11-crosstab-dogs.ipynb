# %% [markdown]
# # **Dogs Dataset - Crosstab Chart**

# %% [markdown]
# **IMPORTANT!!** You must run each code block from top to bottom. First, run the import block, then the "Create a dataframe" block, then the "df.columns" block, etc. The code will not execute until you run the block by clicking on the play button. To see the play button, hover over the [ ] in each block.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Download the [dogs.csv](https://drive.google.com/file/d/1JB7i-u7q3YpuxihimQG5GiGTKac-_MLj/view?usp=sharing) file onto your computer and drag into this Notebook.

# %%
# Create a dataframe from our csv file
df = pd.read_csv("/content/dogs.csv")

# %%
df.columns

# %% [markdown]
# Run the code below to create a cross-tabulation or crosstab chart. A crosstab chart counts how many times combinations of values appear. This chart shows the count of each Max Life Span value per Breed Group.
#
# With your partner, choose 2 columns to discover interesting information. Use mathematical terms (percents, counts, averages, ranges, etc.) and correct use of units of measurement (percents, counts, money, prediction scores, etc.)Remember to update the title and axis labels. Answer the questions below (double click on this box to edit):
#
# 1. Partner Names:
#
# 2. What is the question you are trying to answer with the two column chart?
#
# 3. Were the plot results as you expected, or unexpected?
#
# 4. What is one piece of information someone could learn from your plot?
#
# 5. What, if any, assumptions are you making when reading the plot?
#
#
# Click on the share link at the top right corner of this Notebook and change so 'anyone with the link can view'. Copy the link and post as a comment on the lesson slides.

# %% [markdown]
# # Cross-tabulation (Crosstab) Chart

# %%
# Add a title to the chart using Python print() statement
print('\tMaximum Life Span Counts per Breeding Group\n')

# Create the crosstab chart, specify two column names: index = the rows, and
# columns = the columns.
pd.crosstab(index=df['Breed Group'], columns=[df['Max Life Span']], margins=True)
# Out:
# 	Maximum Life Span Counts per Breeding Group
# Max Life Span  8  10  11  12  13  14  15  16  17  18  20  All
# Breed Group
# Herding        0   0   0   4   2   3   2   1   0   0   0   12
# Hound          1   2   0   4   3   4   3   1   0   0   0   18
# Mixed          0   0   0   0   2   0   0   0   0   0   0    2
# Non-Sporting   0   0   0   0   2   1   5   1   0   0   0    9
# Sporting       0   0   1   5   1   6   5   1   0   0   0   19
# Terrier        0   0   0   0   1   2   5   1   0   0   1   10
# Toy            0   0   0   1   0   4   3   1   1   2   0   12
# Working        1   6   1   8   2   3   2   0   0   0   0   23
# All            2   8   2  22  13  23  25   6   1   2   1  105

# %% [markdown]
# # Crosstab Chart with Heatmap
#
# Importing the Seaborn library, you can use functions to draw a heatmap, which
# darkens the cells with higher values.

# %%
# Add a title to the chart using Python print() statement
print('Maximum Life Span Counts per Breeding Group\n')

# Adding a heatmap to highlight the higher numbers, you must import
# the import seaborn libarary: import seaborn as sns
orange = sns.light_palette("orange", as_cmap=True)

# Create the crosstab chart, specify two column names: index = the rows, and
# columns = the columns.
pd.crosstab(index=df['Breed Group'], columns=[df['Max Life Span']]).style.background_gradient(cmap=orange)
# Out:
# Maximum Life Span Counts per Breeding Group
# <style  type="text/css" >
#     #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row0_col0 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row0_col1 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row0_col2 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row0_col3 {
#             background-color:  #ffcd72;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row0_col4 {
#             background-color:  #ffc04d;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row0_col5 {
#             background-color:  #ffcd72;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row0_col6 {
#             background-color:  #ffd68a;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row0_col7 {
#             background-color:  #ffa500;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row0_col8 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row0_col9 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row0_col10 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row1_col0 {
#             background-color:  #ffa500;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row1_col1 {
#             background-color:  #ffdb99;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row1_col2 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row1_col3 {
#             background-color:  #ffcd72;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row1_col4 {
#             background-color:  #ffa500;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row1_col5 {
#             background-color:  #ffc04d;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row1_col6 {
#             background-color:  #ffc55c;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row1_col7 {
#             background-color:  #ffa500;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row1_col8 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row1_col9 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row1_col10 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row2_col0 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row2_col1 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row2_col2 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row2_col3 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row2_col4 {
#             background-color:  #ffc04d;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row2_col5 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row2_col6 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row2_col7 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row2_col8 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row2_col9 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row2_col10 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row3_col0 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row3_col1 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row3_col2 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row3_col3 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row3_col4 {
#             background-color:  #ffc04d;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row3_col5 {
#             background-color:  #ffe9c0;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row3_col6 {
#             background-color:  #ffa500;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row3_col7 {
#             background-color:  #ffa500;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row3_col8 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row3_col9 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row3_col10 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row4_col0 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row4_col1 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row4_col2 {
#             background-color:  #ffa500;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row4_col3 {
#             background-color:  #ffc356;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row4_col4 {
#             background-color:  #ffdb99;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row4_col5 {
#             background-color:  #ffa500;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row4_col6 {
#             background-color:  #ffa500;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row4_col7 {
#             background-color:  #ffa500;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row4_col8 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row4_col9 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row4_col10 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row5_col0 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row5_col1 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row5_col2 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row5_col3 {
#             background-color:  #fff6e5;
#             color:  #000000;
#         }    #T_1b7f7c2c_de7e_11ea_be4e_0242ac1c0002row5_col4 {
#             background-color:  #ffdb99;
#             color:  #000000
